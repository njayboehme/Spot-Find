# %% [markdown]
# To change the kernel in VSCode, go to the upper right corner where it displays something like "Python 3.10 64-bit". Click on that and change to the .venv located in this folder.

# %%
import numpy as np
import pandas as pd
import gmaps
import gmaps.datasets



gmaps.configure(api_key='AIzaSyBE_CHJPnOl4lfluoP3zJVyiKfAS9etF3M')  # configure key

# need to define project name as a file
lat_long_df = pd.read_csv('/Users/sarahquan/Downloads/world_country_and_usa_states_latitude_and_longitude_values.csv')
lat_long_df['latitude'] = lat_long_df['latitude'].fillna(0)
lat_long_df['longitude'] = lat_long_df['longitude'].fillna(0)
locations = lat_long_df[['latitude', 'longitude']]
states = lat_long_df['usa_state']
print(states)
print(locations)

fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=states))
fig
# print("Showing heatmap")
# heatmap_layer.max_intensity = 100
# heatmap_layer.point_radius = 5
# heatmap_layer.gradient = [
#     'silver',
#     'green',
#     'yellow'
# ]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [1], line 11
#       8 gmaps.configure(api_key='AIzaSyBE_CHJPnOl4lfluoP3zJVyiKfAS9etF3M')  # configure key
#      10 # need to define project name as a file
# ---> 11 lat_long_df = pd.read_csv('/Users/sarahquan/Downloads/world_country_and_usa_states_latitude_and_longitude_values.csv')
#      12 lat_long_df['latitude'] = lat_long_df['latitude'].fillna(0)
#      13 lat_long_df['longitude'] = lat_long_df['longitude'].fillna(0)
#
# File c:\Users\njboe\Desktop\Capstone\Spot-Find\.venv\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd
import gmaps
import gmaps.datasets

gmaps.configure(api_key='AIzaSyBE_CHJPnOl4lfluoP3zJVyiKfAS9etF3M')  # configure key

# need to define project name as a file
lat_long_df = pd.read_csv('/Users/sarahquan/Downloads/purpleairspoof-main/indoor_outdoor_analysis/daily_TEMP_2021.csv')

# remove null and duplicate values
lat_long_df = lat_long_df[~lat_long_df['Latitude'].isnull()]
lat_long_df = lat_long_df[~lat_long_df['Longitude'].isnull()]
lat_long_df = lat_long_df.drop_duplicates(['Latitude', 'Longitude'])
print(lat_long_df['Latitude'], lat_long_df['Longitude'])

# remove rows where temperature mean is < 0, since the heatmap doesn't take negative values
lat_long_df = lat_long_df[lat_long_df['Arithmetic Mean'] >= 0]

locations = lat_long_df[['Latitude', 'Longitude']]
weights = pd.to_numeric(lat_long_df['Arithmetic Mean'])
print(weights)
print(locations)
heatmap_layer = gmaps.heatmap_layer(locations, weights=weights)
heatmap_layer.max_intensity = 100
heatmap_layer.point_radius = 15
# heatmap_layer.gradient = [
#     'silver',
#     'green',
#     'yellow'
# ]
fig = gmaps.figure()
fig.add_layer(heatmap_layer)
fig
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [2], line 8
#       5 gmaps.configure(api_key='AIzaSyBE_CHJPnOl4lfluoP3zJVyiKfAS9etF3M')  # configure key
#       7 # need to define project name as a file
# ----> 8 lat_long_df = pd.read_csv('/Users/sarahquan/Downloads/purpleairspoof-main/indoor_outdoor_analysis/daily_TEMP_2021.csv')
#      10 # remove null and duplicate values
#      11 lat_long_df = lat_long_df[~lat_long_df['Latitude'].isnull()]
#
# File c:\Users\njboe\Desktop\Capstone\Spot-Find\.venv\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
# need to define project name as a file
lat_long_df = pd.read_csv('/Users/sarahquan/Em/BYU/BYU_2021_Fall/ECEn_475/Concept Review/utah_temp_data.csv')

#print(lat_long_df)
# remove null and duplicate values
lat_long_df = lat_long_df[~lat_long_df['Latitude'].isnull()]
lat_long_df = lat_long_df[~lat_long_df['Longitude'].isnull()]
lat_long_df = lat_long_df.drop_duplicates(['Latitude', 'Longitude'])
#print(lat_long_df['Latitude'], lat_long_df['Longitude'])

# remove rows where temperature mean is < 0, since the heatmap doesn't take negative values
lat_long_df = lat_long_df[lat_long_df['Arithmetic Mean'] >= 0]

locations = lat_long_df[['Latitude', 'Longitude']]
weights = pd.to_numeric(lat_long_df['Arithmetic Mean'])
heatmap_layer = gmaps.heatmap_layer(locations, weights=weights)
heatmap_layer.max_intensity = 100
heatmap_layer.point_radius = 25
# heatmap_layer.gradient = [
#     'silver',
#     'green',
#     'yellow'
# ]
fig = gmaps.figure()
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
! conda install pandas -y
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.1
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/sarahquan/anaconda3/envs/map_env
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.2           |   py37hf1fa96c_1         107 KB
#     intel-openmp-2021.3.0      |    hecd8cb5_3375         950 KB
#     mkl-2021.3.0               |     hecd8cb5_517       100.4 MB
#     mkl-service-2.4.0          |   py37h9ed2024_0          44 KB
#     mkl_fft-1.3.0              |   py37h4a7008c_2         159 KB
#     mkl_random-1.2.2           |   py37hb2f4e1b_0         263 KB
#     numexpr-2.7.3              |   py37h5873af2_1         124 KB
# ...

# %%
! conda update -n base -c defaults conda -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/sarahquan/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38hecd8cb5_0         2.9 MB
#     xmltodict-0.12.0           |     pyhd3eb1b0_0          13 KB
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following packages will be UPDATED:
#
#   conda                               4.10.1-py38hecd8cb5_1 --> 4.10.3-py38hecd8cb5_0
#
# The following packages will be DOWNGRADED:
#
#   xmltodict                                     0.12.0-py_0 --> 0.12.0-pyhd3eb1b0_0
#
#
#
# ...
# conda-4.10.3         | 2.9 MB    | ##################################### | 100%
# ...

# %%
! conda install -c conda-forge gmaps -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/sarahquan/anaconda3/envs/map_env
#
#   added / updated specs:
#     - gmaps
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geojson-2.5.0              |             py_0          15 KB  conda-forge
#     gmaps-0.9.0                |             py_0         1.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   geojson            conda-forge/noarch::geojson-2.5.0-py_0
#   gmaps              conda-forge/noarch::gmaps-0.9.0-py_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.9.30-~ --> conda-forge::ca-certificates-2021.10.8-h033912b_0
# ...

# %%
! conda install -c esri arcgis -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/sarahquan/anaconda3/envs/map_env
#
#   added / updated specs:
#     - arcgis
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     arcgis-1.9.1               |        py37_2328         4.8 MB  esri
#     blinker-1.4                |   py37hecd8cb5_0          23 KB
#     brotli-1.0.9               |       hb1e8313_2         398 KB
#     brotlipy-0.7.0             |py37h9ed2024_1003         333 KB
#     cachetools-4.2.2           |     pyhd3eb1b0_0          13 KB
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          35 KB
#     cryptography-3.4.8         |   py37h2fd3fbb_0         725 KB
#     cycler-0.10.0              |           py37_0          14 KB
#     fonttools-4.25.0           |     pyhd3eb1b0_0         632 KB
#     idna-3.2                   |     pyhd3eb1b0_0          48 KB
# ...

# %%
import gmaps
import gmaps.datasets
# Use google maps api
gmaps.configure(api_key='AIzaSyBE_CHJPnOl4lfluoP3zJVyiKfAS9etF3M') # Fill in with your API key
# Get the dataset
earthquake_df = gmaps.datasets.load_dataset_as_df('earthquakes')
#Get the locations from the data set
print(earthquake_df)
locations = earthquake_df[['latitude', 'longitude']]
#Get the magnitude from the data
weights = earthquake_df['magnitude']
# print(weights)
# print(locations)

#Set up your map
fig = gmaps.figure()
fig.add_layer(gmaps.heatmap_layer(locations, weights=weights))
fig
# Out:
#        latitude   longitude  magnitude
# 0     65.193300 -149.072500       1.70
# 1     38.791832 -122.780830       2.10
# 2     38.818001 -122.792168       0.48
# 3     33.601667 -116.727667       0.78
# 4     37.378334 -118.520836       3.64
# ...         ...         ...        ...
# 8599  19.331500 -155.182200       0.80
# 8600  41.819700 -119.622400       2.20
# 8601  38.771999 -122.720497       1.91
# 8602  34.608333 -118.641333       1.93
# 8603  41.905500 -119.625000       4.21
#
# [8604 rows x 3 columns]
# Figure(layout=FigureLayout(height='420px'))

# %%
### generate random coordinates to simulate BYU lat-long coordinates

import random
import sys
import math

lat_min = 40.245876
long_min = -111.643410
lat_max = 40.255901
long_max = -111.658548

def generate_random_data(lat, lon, num_rows):
    for _ in xrange(num_rows):
        lat_min
        hex1 = '%012x' % random.randrange(16**12) # 12 char random string
        flt = float(random.randint(0,100))
        dec_lat = random.random()/1000
        dec_lon = random.random()/1000
        print '%s %.1f %.6f %.6f \n' % (hex1.lower(), flt, lon+dec_lon, lat+dec_lat)

generate_random_data(latitude, longitude, 50)
# Out:
#   File "/var/folders/7b/6hkxtfh52tvgpg36gxwpblw00000gp/T/ipykernel_28503/3649354524.py", line 16
#     print '%s %.1f %.6f %.6f \n' % (hex1.lower(), flt, lon+dec_lon, lat+dec_lat)
#                                ^
# SyntaxError: invalid syntax
